# %%
import tensorflow as tf
import matplotlib.pyplot as plt
from tensorflow.keras.layers import *
from tensorflow.keras.models import Model,Sequential
import zipfile
from keras import optimizers
from tensorflow.keras.preprocessing.image import load_img
from tensorflow.keras.preprocessing.image import img_to_array

# %%
train_path = '/Users/bh/kears/iamge/train'

# %%
classes = 2
height = 128
width = 128
channels = 3

# %%
image_generator = tf.keras.preprocessing.image.ImageDataGenerator(rescale=1/128, 
                                                                  validation_split=0.2
                                                                 )
image_data_train = image_generator.flow_from_directory(train_path,subset='training')
image_data_test = image_generator.flow_from_directory(train_path,subset='validation')
# Out:
# Found 736 images belonging to 2 classes.
# Found 182 images belonging to 2 classes.

# %%
#img = load_img('/Users/bh/adl.png')  # PIL 이미지
#x = img_to_array(img)  # (3, 150, 150) 크기의 NumPy 배열
#x = x.reshape((1,) + x.shape)  # (1, 3, 150, 150) 크기의 NumPy 배열

# 아래 .flow() 함수는 임의 변환된 이미지를 배치 단위로 생성해서
# 지정된 `preview/` 폴더에 저장합니다.
#i = 0
#for batch in image_generator.flow(x, batch_size=1,
#                          save_to_dir='/Users/bh/adle aug' , save_prefix='adel', save_format='jpg'):
#    i += 1
#    if i > 20:
#        break

# %%
resnet50 = tf.keras.applications.resnet50.ResNet50(
           include_top=False,
           weights=None,
           input_tensor=None,
           input_shape=(height,width,channels),
           pooling=None,
           classes=2,
           #**kwargs
)

# %%
resnet50.trainable=True

# %%
model = Sequential([
                 resnet50,
#                 Dense(512,activation='relu'),
#                 BatchNormalization(),
                 GlobalAveragePooling2D(),
                 Dense(classes,activation='softmax')
])

# %%
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  resnet50 (Functional)       (None, 4, 4, 2048)        23587712
#
#  global_average_pooling2d (  (None, 2048)              0
#  GlobalAveragePooling2D)
#
#  dense (Dense)               (None, 2)                 4098
#
# =================================================================
# Total params: 23591810 (90.00 MB)
# Trainable params: 23538690 (89.79 MB)
# Non-trainable params: 53120 (207.50 KB)
# _________________________________________________________________

# %%
model.compile(optimizer=optimizers.legacy.Adam(learning_rate=0.0005),loss='categorical_crossentropy',metrics='accuracy')
#def scheduler(epoch, lr):
#    if epoch < 2:
#        return lr
#    else:
#        return lr * tf.math.exp(-0.1)
#lrs = tf.keras.callbacks.LearningRateScheduler(scheduler)
#model.fit(image_data_train,batch_size=32,epochs=5,callbacks=[lrs],validation_data=(image_data_test),
#          validation_steps =image_data_test.samples/image_data_test.batch_size)
hist = model.fit(image_data_train,batch_size=32,epochs=50,validation_data=(image_data_test),
          validation_steps =image_data_test.samples/image_data_test.batch_size)
# Out:
# Epoch 1/50
# 23/23 [==============================] - 36s 1s/step - loss: 0.9727 - accuracy: 0.7147 - val_loss: 0.7922 - val_accuracy: 0.5330
# Epoch 2/50
# 23/23 [==============================] - 32s 1s/step - loss: 0.4536 - accuracy: 0.8234 - val_loss: 1.8704 - val_accuracy: 0.5330
# Epoch 3/50
# 23/23 [==============================] - 32s 1s/step - loss: 0.3289 - accuracy: 0.8709 - val_loss: 2.1079 - val_accuracy: 0.5330
# Epoch 4/50
# 23/23 [==============================] - 33s 1s/step - loss: 0.2123 - accuracy: 0.9117 - val_loss: 2.8626 - val_accuracy: 0.5330
# Epoch 5/50
# 23/23 [==============================] - 33s 1s/step - loss: 0.1464 - accuracy: 0.9443 - val_loss: 3.3689 - val_accuracy: 0.5330
# Epoch 6/50
# 23/23 [==============================] - 33s 1s/step - loss: 0.1009 - accuracy: 0.9728 - val_loss: 4.6935 - val_accuracy: 0.5330
# Epoch 7/50
# 23/23 [==============================] - 34s 1s/step - loss: 0.0452 - accuracy: 0.9823 - val_loss: 5.9026 - val_accuracy: 0.5330
# Epoch 8/50
# 23/23 [==============================] - 35s 2s/step - loss: 0.0540 - accuracy: 0.9851 - val_loss: 2.4083 - val_accuracy: 0.5330
# Epoch 9/50
# 23/23 [==============================] - 36s 2s/step - loss: 0.0860 - accuracy: 0.9755 - val_loss: 3.1165 - val_accuracy: 0.5330
# Epoch 10/50
# 23/23 [==============================] - 37s 2s/step - loss: 0.0547 - accuracy: 0.9851 - val_loss: 3.5262 - val_accuracy: 0.5330
# Epoch 11/50
# 23/23 [==============================] - 37s 2s/step - loss: 0.0728 - accuracy: 0.9783 - val_loss: 2.4982 - val_accuracy: 0.5330
# Epoch 12/50
# 23/23 [==============================] - 37s 2s/step - loss: 0.0847 - accuracy: 0.9647 - val_loss: 3.1674 - val_accuracy: 0.5440
# Epoch 13/50
# 23/23 [==============================] - 37s 2s/step - loss: 0.0262 - accuracy: 0.9932 - val_loss: 5.4230 - val_accuracy: 0.5330
# Epoch 14/50
# 23/23 [==============================] - 37s 2s/step - loss: 0.0391 - accuracy: 0.9891 - val_loss: 3.2639 - val_accuracy: 0.5934
# Epoch 15/50
# 23/23 [==============================] - 38s 2s/step - loss: 0.0539 - accuracy: 0.9851 - val_loss: 1.6423 - val_accuracy: 0.6648
# Epoch 16/50
# 23/23 [==============================] - 38s 2s/step - loss: 0.0315 - accuracy: 0.9905 - val_loss: 0.6383 - val_accuracy: 0.7527
# Epoch 17/50
# 23/23 [==============================] - 39s 2s/step - loss: 0.0129 - accuracy: 0.9946 - val_loss: 0.8738 - val_accuracy: 0.7857
# Epoch 18/50
# 23/23 [==============================] - 38s 2s/step - loss: 0.0269 - accuracy: 0.9905 - val_loss: 0.3302 - val_accuracy: 0.9176
# Epoch 19/50
# 23/23 [==============================] - 38s 2s/step - loss: 0.0214 - accuracy: 0.9946 - val_loss: 0.4242 - val_accuracy: 0.9121
# Epoch 20/50
# 23/23 [==============================] - 39s 2s/step - loss: 0.0289 - accuracy: 0.9905 - val_loss: 0.8324 - val_accuracy: 0.8462
# Epoch 21/50
# 23/23 [==============================] - 37s 2s/step - loss: 0.0082 - accuracy: 0.9959 - val_loss: 0.6625 - val_accuracy: 0.8956
# Epoch 22/50
# 23/23 [==============================] - 38s 2s/step - loss: 0.0070 - accuracy: 0.9973 - val_loss: 0.5193 - val_accuracy: 0.9176
# Epoch 23/50
# 23/23 [==============================] - 37s 2s/step - loss: 0.0115 - accuracy: 0.9946 - val_loss: 0.6220 - val_accuracy: 0.8846
# Epoch 24/50
# 23/23 [==============================] - 37s 2s/step - loss: 0.0149 - accuracy: 0.9946 - val_loss: 0.5913 - val_accuracy: 0.9176
# Epoch 25/50
# 23/23 [==============================] - 37s 2s/step - loss: 0.0430 - accuracy: 0.9851 - val_loss: 0.2736 - val_accuracy: 0.9560
# Epoch 26/50
# 23/23 [==============================] - 37s 2s/step - loss: 0.0165 - accuracy: 0.9932 - val_loss: 0.3218 - val_accuracy: 0.9176
# Epoch 27/50
# 23/23 [==============================] - 38s 2s/step - loss: 0.0187 - accuracy: 0.9932 - val_loss: 0.4281 - val_accuracy: 0.9121
# Epoch 28/50
# 23/23 [==============================] - 38s 2s/step - loss: 0.0193 - accuracy: 0.9959 - val_loss: 0.4157 - val_accuracy: 0.9231
# Epoch 29/50
# 23/23 [==============================] - 37s 2s/step - loss: 0.0086 - accuracy: 0.9973 - val_loss: 0.2338 - val_accuracy: 0.9615
# Epoch 30/50
# 23/23 [==============================] - 37s 2s/step - loss: 0.0200 - accuracy: 0.9932 - val_loss: 0.5199 - val_accuracy: 0.8956
# Epoch 31/50
# 23/23 [==============================] - 38s 2s/step - loss: 0.0434 - accuracy: 0.9837 - val_loss: 0.3317 - val_accuracy: 0.9286
# Epoch 32/50
# 23/23 [==============================] - 38s 2s/step - loss: 0.0158 - accuracy: 0.9946 - val_loss: 0.2795 - val_accuracy: 0.9231
# Epoch 33/50
# 23/23 [==============================] - 38s 2s/step - loss: 0.0469 - accuracy: 0.9837 - val_loss: 2.3146 - val_accuracy: 0.7198
# Epoch 34/50
# 23/23 [==============================] - 37s 2s/step - loss: 0.0561 - accuracy: 0.9837 - val_loss: 0.6078 - val_accuracy: 0.8516
# Epoch 35/50
# 23/23 [==============================] - 37s 2s/step - loss: 0.0266 - accuracy: 0.9878 - val_loss: 0.5924 - val_accuracy: 0.9231
# Epoch 36/50
# 23/23 [==============================] - 37s 2s/step - loss: 0.0296 - accuracy: 0.9905 - val_loss: 0.5258 - val_accuracy: 0.8956
# Epoch 37/50
# 23/23 [==============================] - 38s 2s/step - loss: 0.0260 - accuracy: 0.9918 - val_loss: 0.3987 - val_accuracy: 0.9341
# Epoch 38/50
# 23/23 [==============================] - 38s 2s/step - loss: 0.0270 - accuracy: 0.9878 - val_loss: 0.3972 - val_accuracy: 0.9286
# Epoch 39/50
# 23/23 [==============================] - 37s 2s/step - loss: 0.0277 - accuracy: 0.9864 - val_loss: 0.2551 - val_accuracy: 0.9341
# Epoch 40/50
# 23/23 [==============================] - 37s 2s/step - loss: 0.0163 - accuracy: 0.9932 - val_loss: 0.3672 - val_accuracy: 0.9231
# Epoch 41/50
# 23/23 [==============================] - 37s 2s/step - loss: 0.0145 - accuracy: 0.9959 - val_loss: 0.3409 - val_accuracy: 0.9451
# Epoch 42/50
# 23/23 [==============================] - 37s 2s/step - loss: 0.0055 - accuracy: 0.9973 - val_loss: 0.4807 - val_accuracy: 0.9066
# Epoch 43/50
# 23/23 [==============================] - 39s 2s/step - loss: 0.0015 - accuracy: 1.0000 - val_loss: 0.6659 - val_accuracy: 0.8901
# Epoch 44/50
# 23/23 [==============================] - 40s 2s/step - loss: 5.0817e-04 - accuracy: 1.0000 - val_loss: 0.6899 - val_accuracy: 0.9011
# Epoch 45/50
# 23/23 [==============================] - 39s 2s/step - loss: 0.0021 - accuracy: 1.0000 - val_loss: 0.5978 - val_accuracy: 0.9066
# Epoch 46/50
# 23/23 [==============================] - 40s 2s/step - loss: 4.9187e-04 - accuracy: 1.0000 - val_loss: 0.5334 - val_accuracy: 0.9121
# Epoch 47/50
# 23/23 [==============================] - 40s 2s/step - loss: 1.8397e-04 - accuracy: 1.0000 - val_loss: 0.4647 - val_accuracy: 0.9286
# Epoch 48/50
# 23/23 [==============================] - 40s 2s/step - loss: 1.7529e-04 - accuracy: 1.0000 - val_loss: 0.4257 - val_accuracy: 0.9341
# Epoch 49/50
# 23/23 [==============================] - 38s 2s/step - loss: 2.0596e-04 - accuracy: 1.0000 - val_loss: 0.3829 - val_accuracy: 0.9341
# Epoch 50/50
# 23/23 [==============================] - 38s 2s/step - loss: 1.3180e-04 - accuracy: 1.0000 - val_loss: 0.3407 - val_accuracy: 0.9396

# %%
import matplotlib.pyplot as plt

loss = hist.history['loss']
acc = hist.history['accuracy']

val_loss = hist.history['val_loss']
val_acc = hist.history['val_accuracy']

epochs = range(1, len(loss)+1)

plt.figure(figsize=(10,7))
plt.subplots_adjust(wspace=0.5)

plt.subplot(1,2,1)
plt.plot(epochs, loss, 'bo-', label='Training loss')
plt.plot(epochs, val_loss, 'rx--', label='Vaildation loss')
plt.title('Loss')
plt.xlabel('Epochs')
plt.ylabel('loss')
plt.grid()
plt.legend()

plt.subplot(1,2,2)
plt.plot(epochs, acc, 'bo-', label='Training accuarcy')
plt.plot(epochs, val_acc, 'rx--', label='Vaildation accuracy')
plt.title('Accuracy')
plt.xlabel('Epochs')
plt.ylabel('accuracy')
plt.grid()
plt.legend()

# %%
from tensorflow.keras.preprocessing.image import load_img
from tensorflow.keras.preprocessing.image import img_to_array
import matplotlib.pyplot as plt
import numpy as np

# %%
img_height = 128
img_width = 128

filename = ['/Users/bh/kears/iamge/test/adélie penguin/adélie_penguin_95.jpg','/Users/bh/kears/iamge/test/king penguin/king penguin44.jpg','/Users/bh/kears/iamge/test/gentoo penguin/gentoo_penguin_45.jpg']

predict_dictionary = {0:'adelie penguin',1:'gentoo penguin',2: 'king penguin'}

for file in filename:
    original = load_img(file, target_size = (img_height,img_width))

    numpy_image = img_to_array(original)
    plt.imshow(np.uint8(numpy_image))
    plt.show()
    print("numpy array size : ", numpy_image.shape)
    image_batch = np.expand_dims(numpy_image , axis = 0)

    predict = np.argmax(model.predict(image_batch/128.))

    print('결과 : ',predict_dictionary[predict])
# Out:
# numpy array size :  (128, 128, 3)
# 1/1 [==============================] - 1s 861ms/step
# 결과 :  adelie penguin
# numpy array size :  (128, 128, 3)
# 1/1 [==============================] - 0s 29ms/step
# 결과 :  gentoo penguin
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[13], line 9
#       6 predict_dictionary = {0:'adelie penguin',1:'gentoo penguin',2: 'king penguin'}
#       8 for file in filename:
# ----> 9     original = load_img(file, target_size = (img_height,img_width))
#      11     numpy_image = img_to_array(original)
#      12     plt.imshow(np.uint8(numpy_image))
#
# File ~/miniforge3/envs/env_tf/lib/python3.8/site-packages/keras/src/utils/image_utils.py:422, in load_img(path, grayscale, color_mode, target_size, interpolation, keep_aspect_ratio)
#     420     if isinstance(path, pathlib.Path):
#     421         path = str(path.resolve())
# --> 422     with open(path, "rb") as f:
#     423         img = pil_image.open(io.BytesIO(f.read()))
#     424 else:
#
# FileNotFoundError: [Errno 2] No such file or directory: '/Users/bh/kears/iamge/test/gentoo penguin/gentoo_penguin_45.jpg'

# %%
model.save_weights('/Users/bh/kears/origin/weight')

# %%
test_datagen = tf.keras.preprocessing.image.ImageDataGenerator(rescale = 1./128)
test_dir = '/Users/bh/kears/iamge/test'
test_Gen = test_datagen.flow_from_directory(test_dir, batch_size = 32)
loss, accuracy = model.evaluate(test_Gen,
                                steps = test_Gen.samples/test_Gen.batch_size)

print('Loss = {:.5f}'.format(loss))
print('Acc - {:.5f}'.format(accuracy))
